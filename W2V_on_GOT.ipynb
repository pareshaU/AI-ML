# %% [markdown]
# <a href="https://colab.research.google.com/github/pareshaU/AI-ML/blob/main/W2V_on_GOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
story=[]

# %%
for file in os.listdir("/content/GOT_Data"):
  f=open("/content/GOT_Data/001ssb.txt",encoding="unicode_escape")

corpus=f.read()

# %% [markdown]
# convert data to token as sentancees

# %%
raw_sent=sent_tokenize(corpus)

# %%
for i in raw_sent:
  print(simple_preprocess(i))
# Out:
# Streaming output truncated to the last 5000 lines.
# ['her', 'handmaids', 'and', 'the', 'men', 'of', 'her', 'khas', 'came', 'after', 'smiling', 'and', 'jesting', 'among', 'themselves']
# ['dothraki', 'hooves', 'had', 'torn', 'the', 'earth', 'and', 'trampled', 'the', 'rye', 'and', 'lentils', 'into', 'the', 'ground', 'while', 'arakhs', 'and', 'arrows', 'had', 'sown', 'terrible', 'new', 'crop', 'and', 'watered', 'it', 'with', 'blood']
# ['dying', 'horses', 'lifted', 'their', 'heads', 'and', 'screamed', 'at', 'her', 'as', 'she', 'rode', 'past']
# ['wounded', 'men', 'moaned', 'and', 'prayed']
# ['jaqqa', 'rhan', 'moved', 'among', 'them', 'the', 'mercy', 'men', 'with', 'their', 'heavy', 'axes', 'taking', 'harvest', 'of', 'heads', 'from', 'the', 'dead', 'and', 'dying', 'alike']
# ['after', 'them', 'would', 'scurry', 'flock', 'of', 'small', 'girls', 'pulling', 'arrows', 'from', 'the', 'corpses', 'to', 'fill', 'their', 'baskets']
# ...
